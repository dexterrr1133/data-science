# %% [markdown]
# ### **Data Mining Using SQL**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# !pip install prettytable==0.7.2
# !pip install ipython-sql
# Out:
# Collecting prettytable==0.7.2
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (pyproject.toml): started
#   Building wheel for prettytable (pyproject.toml): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13768 sha256=bf86778999cad0808bb82f1eba2bd5730b26cc5475b6d037bc24fbd02ee7398b
#   Stored in directory: c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\b1\e4\65\051f9bd54c89d377db5ca942a672439c36cbf5ceff8e8902e0
# Successfully built prettytable
# Installing collected packages: prettytable
# Successfully installed prettytable-0.7.2
# [notice] A new release of pip is available: 24.0 -> 26.0
# [notice] To update, run: C:\Users\linus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ^C
# [notice] A new release of pip is available: 24.0 -> 26.0
# [notice] To update, run: C:\Users\linus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: prettytable in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (9.10.0)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Downloading sqlalchemy-2.0.46-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet>=1 (from sqlalchemy>=2.0->ipython-sql)
#   Downloading greenlet-3.3.1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.5.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\linus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading sqlalchemy-2.0.46-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 1.3 MB/s eta 0:00:02
#     --------------------------------------- 0.0/2.1 MB 960.0 kB/s eta 0:00:03
#     --------------------------------------- 0.0/2.1 MB 960.0 kB/s eta 0:00:03
#     --------------------------------------- 0.0/2.1 MB 960.0 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.1 MB 435.7 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.1 MB 435.7 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.1 MB 363.1 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 342.4 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 342.4 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 340.5 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 340.5 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.1 MB 327.7 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.1 MB 327.7 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.1 MB 318.3 kB/s eta 0:00:07
#    --- ------------------------------------ 0.2/2.1 MB 318.3 kB/s eta 0:00:07
#    --- ------------------------------------ 0.2/2.1 MB 296.1 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.2/2.1 MB 299.1 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.2/2.1 MB 299.1 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.2/2.1 MB 299.1 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.2/2.1 MB 299.1 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 293.5 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 293.5 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 285.3 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 285.3 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 285.3 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 273.1 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 273.1 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.1 MB 273.1 kB/s eta 0:00:07
#    ------ --------------------------------- 0.3/2.1 MB 268.8 kB/s eta 0:00:07
#    ------ --------------------------------- 0.4/2.1 MB 268.4 kB/s eta 0:00:07
#    ------ --------------------------------- 0.4/2.1 MB 268.4 kB/s eta 0:00:07
#    ------ --------------------------------- 0.4/2.1 MB 268.4 kB/s eta 0:00:07
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------ --------------------------------- 0.4/2.1 MB 252.0 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 224.5 kB/s eta 0:00:08
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 194.6 kB/s eta 0:00:09
#    ------- -------------------------------- 0.4/2.1 MB 179.5 kB/s eta 0:00:10
#    ------- -------------------------------- 0.4/2.1 MB 179.5 kB/s eta 0:00:10
#    ------- -------------------------------- 0.4/2.1 MB 179.5 kB/s eta 0:00:10
#    ------- -------------------------------- 0.4/2.1 MB 179.5 kB/s eta 0:00:10
#    -------- ------------------------------- 0.4/2.1 MB 175.3 kB/s eta 0:00:10
#    -------- ------------------------------- 0.4/2.1 MB 175.3 kB/s eta 0:00:10
#    -------- ------------------------------- 0.4/2.1 MB 175.3 kB/s eta 0:00:10
#    -------- ------------------------------- 0.4/2.1 MB 175.3 kB/s eta 0:00:10
#    -------- ------------------------------- 0.5/2.1 MB 166.7 kB/s eta 0:00:11
#    -------- ------------------------------- 0.5/2.1 MB
kB ? eta -:--:--
#    - -------------------------------------- 10.2/226.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/226.5 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/226.5 kB 163.8 kB/s eta 0:00:02
#    ----- --------------------------------- 30.7/226.5 kB 163.8 kB/s eta 0:00:02
#    ------- ------------------------------- 41.0/226.5 kB 140.3 kB/s eta 0:00:02
#    ------- ------------------------------- 41.0/226.5 kB 140.3 kB/s eta 0:00:02
#    ---------- ---------------------------- 61.4/226.5 kB 172.4 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/226.5 kB 191.1 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/226.5 kB 191.1 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/226.5 kB 191.1 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/226.5 kB 191.1 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/226.5 kB 191.1 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/226.5 kB 177.2 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/226.5 kB 177.2 kB/s eta 0:00:01
#    -------------------- ----------------- 122.9/226.5 kB 160.2 kB/s eta 0:00:01
#    -------------------- ----------------- 122.9/226.5 kB 160.2 kB/s eta 0:00:01
#    ------------------------ ------------- 143.4/226.5 kB 163.9 kB/s eta 0:00:01
#    ------------------------ ------------- 143.4/226.5 kB 163.9 kB/s eta 0:00:01
#    ------------------------ ------------- 143.4/226.5 kB 163.9 kB/s eta 0:00:01
#    ------------------------ ------------- 143.4/226.5 kB 163.9 kB/s eta 0:00:01
#    --------------------------- ---------- 163.8/226.5 kB 161.2 kB/s eta 0:00:01
#    --------------------------- ---------- 163.8/226.5 kB 161.2 kB/s eta 0:00:01
#    ----------------------------- -------- 174.1/226.5 kB 156.5 kB/s eta 0:00:01
#    -------------------------------- ----- 194.6/226.5 kB 163.8 kB/s eta 0:00:01
#    -------------------------------- ----- 194.6/226.5 kB 163.8 kB/s eta 0:00:01
#    ---------------------------------- --- 204.8/226.5 kB 161.7 kB/s eta 0:00:01
#    -------------------------------------  225.3/226.5 kB 169.9 kB/s eta 0:00:01
#    -------------------------------------- 226.5/226.5 kB 164.8 kB/s eta 0:00:00
# Installing collected packages: ipython-genutils, sqlparse, greenlet, sqlalchemy, ipython-sql
# Successfully installed greenlet-3.3.1 ipython-genutils-0.2.0 ipython-sql-0.5.0 sqlalchemy-2.0.46 sqlparse-0.5.5

# %%
# Set-up
# %load_ext sql
# %sql sqlite://
import pandas as pd

# %%
# Load tables from CSV files
# Shop
with open('Shop.csv') as f: Shop = pd.read_csv(f, index_col=0)
# %sql drop table if exists Shop;
# %sql --persist Shop
# Movies
with open('Movies.csv') as f: Movies = pd.read_csv(f, index_col=0)
# %sql drop table if exists Movies;
# %sql --persist Movies
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted movies'

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %%
# %%sql
# select * from Shop
# Out:
#  * sqlite://
# Done.
# [(1, 'milk'),
#  (1, 'eggs'),
#  (1, 'juice'),
#  (2, 'milk'),
#  (2, 'juice'),
#  (2, 'cookies'),
#  (3, 'eggs'),
#  (3, 'chips'),
#  (4, 'milk'),
#  (4, 'eggs'),
#  (5, 'milk'),
#  (5, 'juice'),
#  (5, 'cookies'),
#  (5, 'chips')]

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### All pairs of items occurring together

# %%
# %%sql
# select T1.item as item1, T2.item as item2
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'milk'),
#  ('eggs', 'juice'),
#  ('juice', 'milk'),
#  ('juice', 'milk'),
#  ('cookies', 'milk'),
#  ('cookies', 'juice'),
#  ('chips', 'eggs'),
#  ('eggs', 'milk'),
#  ('juice', 'milk'),
#  ('cookies', 'milk'),
#  ('cookies', 'juice'),
#  ('chips', 'milk'),
#  ('chips', 'juice'),
#  ('chips', 'cookies')]

# %% [markdown]
# #### Now with number of transactions they occur together in

# %%
# %%sql
# select T1.item as item1, T2.item as item2, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('chips', 'cookies', 1),
#  ('chips', 'eggs', 1),
#  ('chips', 'juice', 1),
#  ('chips', 'milk', 1),
#  ('cookies', 'juice', 2),
#  ('cookies', 'milk', 2),
#  ('eggs', 'juice', 1),
#  ('eggs', 'milk', 2),
#  ('juice', 'milk', 3)]

# %% [markdown]
# #### Total number of transactions

# %%
# %%sql
# select count(distinct TID) from Shop
# Out:
#  * sqlite://
# Done.
# [(5,)]

# %% [markdown]
# #### Put it together for frequent item-sets

# %%
support = .32
print(support)
# Out:
# 0.35

# %%
# %%sql
# select T1.item as item1, T2.item as item2
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('cookies', 'juice'),
#  ('cookies', 'milk'),
#  ('eggs', 'milk'),
#  ('juice', 'milk')]

# %% [markdown]
# ### Frequent item-sets of three

# %% [markdown]
# #### All triples of items occurring together

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'juice', 'milk'),
#  ('cookies', 'juice', 'milk'),
#  ('cookies', 'juice', 'milk'),
#  ('chips', 'juice', 'milk'),
#  ('chips', 'cookies', 'milk'),
#  ('chips', 'cookies', 'juice')]

# %% [markdown]
# #### Now with number of transactions they occur together in

# %%
# %%sql
# select distinct T1.item as item1, T2.item as item2, T3.item as item3, count()
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('chips', 'cookies', 'juice', 1),
#  ('chips', 'cookies', 'milk', 1),
#  ('chips', 'juice', 'milk', 1),
#  ('cookies', 'juice', 'milk', 2),
#  ('eggs', 'juice', 'milk', 1)]

# %% [markdown]
# #### Put it together for frequent item-sets

# %%
support = .28
print(support)
# Out:
# 0.3

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('cookies', 'juice', 'milk')]

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
# %%sql
# select * from Movies limit 15
# Out:
#  * sqlite://
# Done.
# [(145755, 'The Fault in Our Stars'),
#  (145755, 'Boyhood'),
#  (145755, 'Big Hero 6'),
#  (145755, 'The Imitation Game'),
#  (145755, 'Inside Out'),
#  (117070, 'Inside Out'),
#  (239040, 'Inside Out'),
#  (177796, 'Gone Girl'),
#  (177796, 'Magic Mike XXL'),
#  (126875, 'The Imitation Game'),
#  (126875, 'Inside Out'),
#  (55295, 'The Imitation Game'),
#  (55295, 'Inside Out'),
#  (92094, 'The Fault in Our Stars'),
#  (92094, 'Boyhood')]

# %%
# %%sql
# select count(distinct TID) as numUsers,
#        count(distinct item) as numMovies
# from Movies
# Out:
#  * sqlite://
# Done.
# [(1382, 123)]

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
support = 0.026
print(support)
# Out:
# 0.026

# %%
# %%sql
# select m1.item, m2.item, m3.item, count(m1.tid) as support_count
# from movies m1
# join movies m2 on m1.tid = m2.tid and m1.item < m2.item
# join movies m3 on m2.tid = m3.tid and m2.item < m3.item
# group by m1.item, m2.item, m3.item
# having support_count > 35.932
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 56),
#  ('Big Hero 6', 'Boyhood', 'Inside Out', 39),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 57),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 43),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 44),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 85),
#  ('Big Hero 6', 'Gone Girl', 'The Imitation Game', 119),
#  ('Big Hero 6', 'Inside Out', 'The Imitation Game', 102),
#  ('Boyhood', 'Fury', 'Gone Girl', 43),
#  ('Boyhood', 'Fury', 'The Imitation Game', 43),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 54),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 95),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 52),
#  ('Fury', 'Gone Girl', 'Inside Out', 40),
#  ('Fury', 'Gone Girl', 'The Imitation Game', 70),
#  ('Fury', 'Inside Out', 'The Imitation Game', 39),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 103)]

# %%
# %%sql
# select m1.item, m2.item, m3.item, m4.item, count(m1.tid) as support_count
# from movies m1
# join movies m2 on m1.tid = m2.tid and m1.item < m2.item
# join movies m3 on m2.tid = m3.tid and m2.item < m3.item
# join movies m4 on m3.tid = m4.tid and m3.item < m4.item
# group by m1.item, m2.item, m3.item, m4.item
# having support_count > 42.0
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 'The Imitation Game', 46),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 'The Imitation Game', 59)]

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %%
support = .55
confidence = .60
print(support, confidence)
# Out:
# 0.55 0.6

# %% [markdown]
# #### First compute frequent item-sets of one item with specified support, as candidate left-hand sides of assocation rules; include number of transactions

# %%
# %%sql
# select item, count() as numtrans
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### Do the same query but save the result in a table called "Frequents"

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item, numtrans);
# insert into Frequent
# select item, count()
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 3 rows affected.
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### All pairs with frequent left-hand side, number of transactions for left-hand side, and number of transactions for both

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, F.numtrans as LHS_count, count() as both
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'chips', 3, 1),
#  ('eggs', 'juice', 3, 1),
#  ('eggs', 'milk', 3, 2),
#  ('juice', 'chips', 3, 1),
#  ('juice', 'cookies', 3, 2),
#  ('juice', 'eggs', 3, 1),
#  ('juice', 'milk', 3, 3),
#  ('milk', 'chips', 4, 1),
#  ('milk', 'cookies', 4, 2),
#  ('milk', 'eggs', 4, 2),
#  ('milk', 'juice', 4, 3)]

# %% [markdown]
# #### Add check for specified confidence to get final result

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('eggs', 'milk'), ('juice', 'cookies'), ('juice', 'milk'), ('milk', 'juice')]

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %%
support = .57
confidence = .62
print(support, confidence)
# Out:
# 0.55 0.6

# %% [markdown]
# #### First compute frequent item-sets of two items with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, numtrans);
# insert into Frequent
# select T1.item, T2.item, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 1 rows affected.
# Done.
# [('juice', 'milk', 3)]

# %% [markdown]
# #### All triples with frequent left-hand side, number of transactions for left-hand side, and number of transactions for all three

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'chips', 3, 1),
#  ('juice', 'milk', 'cookies', 3, 2),
#  ('juice', 'milk', 'eggs', 3, 1)]

# %% [markdown]
# #### Add check for specified confidence to get final result

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'cookies')]

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# #### Compute overall frequency of each item -- needed for lift calculation

# %%
# %%sql
# select item, 1.0*count() / (select count(distinct TID) from Shop)
# from Shop
# group by item
# Out:
#  * sqlite://
# Done.
# [('chips', 0.4),
#  ('cookies', 0.4),
#  ('eggs', 0.6),
#  ('juice', 0.6),
#  ('milk', 0.8)]

# %% [markdown]
# #### Do the same query but save the result in a table called "ItemFreq"

# %%
# %%sql
# drop table if exists ItemFreq;
# create table ItemFreq(item, freq);
# insert into ItemFreq
# select item, 1.0*count() / (select count(distinct TID) from Shop)
# from Shop
# group by item;
# select * from ItemFreq
# Out:
#  * sqlite://
# Done.
# Done.
# 5 rows affected.
# Done.
# [('chips', 0.4),
#  ('cookies', 0.4),
#  ('eggs', 0.6),
#  ('juice', 0.6),
#  ('milk', 0.8)]

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %%
support = .55
print(support)
# Out:
# 0.55

# %% [markdown]
# #### First compute frequent item-sets of one item with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions.

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item, numtrans);
# insert into Frequent
# select item, count()
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 3 rows affected.
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### All pairs with frequent left-hand side, number of transactions for left-hand side, and number of transactions for both

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'chips', 3, 1),
#  ('eggs', 'juice', 3, 1),
#  ('eggs', 'milk', 3, 2),
#  ('juice', 'chips', 3, 1),
#  ('juice', 'cookies', 3, 2),
#  ('juice', 'eggs', 3, 1),
#  ('juice', 'milk', 3, 3),
#  ('milk', 'chips', 4, 1),
#  ('milk', 'cookies', 4, 2),
#  ('milk', 'eggs', 4, 2),
#  ('milk', 'juice', 4, 3)]

# %% [markdown]
# #### Add check for lift > 1 to get final result

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, (1.0*count() / F.numtrans) / I.freq as lift
# from Shop T1, Shop T2, Frequent F, ItemFreq I
# where T1.item = F.item
# and T1.TID = T2.TID
# and T2.item = I.item
# and T1.item != T2.item
# group by T1.item, T2.item
# having (1.0*count() / F.numtrans) / I.freq > 1
# Out:
#  * sqlite://
# Done.
# [('juice', 'cookies', 1.6666666666666665),
#  ('juice', 'milk', 1.25),
#  ('milk', 'cookies', 1.25),
#  ('milk', 'juice', 1.25)]

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %%
support = .55
print(support)
# Out:
# 0.55

# %% [markdown]
# #### First compute frequent item-sets of two items with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, numtrans);
# insert into Frequent
# select T1.item, T2.item, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 1 rows affected.
# Done.
# [('juice', 'milk', 3)]

# %% [markdown]
# #### All triples with frequent left-hand side, number of transactions for left-hand side, and number of transactions for all three

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'chips', 3, 1),
#  ('juice', 'milk', 'cookies', 3, 2),
#  ('juice', 'milk', 'eggs', 3, 1)]

# %% [markdown]
# #### Add check for lift > 1 to get final result

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, (1.0*count() / F.numtrans) / I.freq as lift
# from Shop T1, Shop T2, Shop T3, Frequent F, ItemFreq I
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.item = I.item
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# having (1.0*count() / F.numtrans) / I.freq > 1
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'cookies', 1.6666666666666665)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
support = 0.035
confidence = 0.70
print(support, confidence)
# Out:
# 0.035 0.7

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, item3, numtrans);
#
# insert into Frequent
# select T1.item, T2.item, T3.item, count()
# from Movies T1, Movies T2, Movies T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support;
#
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 10 rows affected.
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 56),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 57),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 85),
#  ('Big Hero 6', 'Gone Girl', 'The Imitation Game', 119),
#  ('Big Hero 6', 'Inside Out', 'The Imitation Game', 102),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 54),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 95),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 52),
#  ('Fury', 'Gone Girl', 'The Imitation Game', 70),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 103)]

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as LHS3, T4.item as RHS
# from Movies T1, Movies T2, Movies T3, Movies T4, Frequent F
# where T1.item = F.item1 and T2.item = F.item2 and T3.item = F.item3
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.TID = T4.TID
# and T4.item not in (F.item1, F.item2, F.item3)
# group by T1.item, T2.item, T3.item, T4.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 'The Imitation Game'),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 'Gone Girl'),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 'The Imitation Game'),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 'Gone Girl')]

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20.

# %%
support = 0.018
lift = 3.5
print(support, lift)
# Out:
# 0.018 3.5

# %%
# %%sql
# drop table if exists ItemFreq;
# create table ItemFreq(item, freq);
#
# insert into ItemFreq
# select item, 1.0*count() / (select count(distinct TID) from Movies)
# from Movies
# group by item;
# Out:
#  * sqlite://
# Done.
# Done.
# 123 rows affected.
# []

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, item3, numtrans);
#
# insert into Frequent
# select T1.item, T2.item, T3.item, count()
# from Movies T1, Movies T2, Movies T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support;
# Out:
#  * sqlite://
# Done.
# Done.
# 29 rows affected.
# []

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as LHS3, T4.item as RHS,
#        (1.0*count() / F.numtrans) / I.freq as lift_value
# from Movies T1, Movies T2, Movies T3, Movies T4, Frequent F, ItemFreq I
# where T1.item = F.item1 and T2.item = F.item2 and T3.item = F.item3
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.TID = T4.TID
# and T4.item = I.item
# and T4.item not in (F.item1, F.item2, F.item3)
# group by T1.item, T2.item, T3.item, T4.item
# having 1.0*count() / (select count(distinct TID) from Movies) >= :support
#    and lift_value > :lift
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 'Fury', 4.828416149068323),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 'Fury', 4.919399949148232),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 'Boyhood', 3.805997552019584),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 'Boyhood', 3.85725677830941),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 'Fury', 4.111212814645309),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 'Fury', 3.5002110595187843)]
